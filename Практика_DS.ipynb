# %% [markdown]
# <a href="https://colab.research.google.com/github/mambettt/SummerDS/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# установка библиотеки opendatasets
# !pip install opendatasets

# %%
# импортируем
import opendatasets as od

# %%
# скачиваем набор данных
od.download("https://www.kaggle.com/datasets/joebeachcapital/differentiated-thyroid-cancer-recurrence/data?select=Thyroid_Diff.csv")
# Out:
# Skipping, found downloaded files in "./differentiated-thyroid-cancer-recurrence" (use force=True to force download)

# %%
# загрузка датасета
df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')

# %%
# ознакомление с данными
print(df.head())
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# ...

# %%
#сводная статистика по числовым столбцам
print(df.describe())
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
# типы переменных
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
# позволяет быстро оценить, какие столбцы содержат пропущенные данные и в каком количестве
print(df.isnull().sum())
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
# просмотр столбцов в DataFrame
df.columns
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred'],
#       dtype='object')

# %% [markdown]
# **EDA**

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных
df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')

# Список классов
columns_to_plot = ['Age', 'Gender', 'Smoking', 'Hx Smoking',
                   'Thyroid Function', 'Physical Examination', 'Adenopathy',
                   'Pathology', 'Focality', 'Risk', 'T', 'N', 'M', 'Stage',
                   'Response', 'Recurred']

# Создание гистограмм
plt.figure(figsize=(15, 20))
for i, column in enumerate(columns_to_plot):
    plt.subplot(5, 4, i + 1)
    if df[column].dtype == 'object':
        df[column].value_counts().plot(kind='bar')
        plt.title(column)
    else:
        df[column].plot(kind='hist', bins=20)
        plt.title(column)
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных
df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')

# Список классов
columns_to_plot = ['Age', 'Gender', 'Smoking', 'Hx Smoking',
                   'Thyroid Function', 'Physical Examination', 'Adenopathy',
                   'Pathology', 'Focality', 'Risk', 'T', 'N', 'M', 'Stage',
                   'Response', 'Recurred']

# Создание фигуры с графиками
plt.figure(figsize=(15, 20))
for i, column in enumerate(columns_to_plot):
    plt.subplot(5, 4, i + 1)
    if df[column].dtype == 'object':
        sns.countplot(x=column, data=df)
        plt.title(column)
        plt.xticks(rotation=45)
    else:
        sns.histplot(df[column], bins=20, kde=True)
        plt.title(column)

    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')


numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# График размаха для числовых переменных
plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(y=df[column])
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
# Графики с плотностью (KDE plots)
plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns):
    plt.subplot(4, 4, i + 1)
    sns.kdeplot(df[column], fill=True, label='Density', color='blue')
    plt.title(f'Плотность {column}')
    plt.legend()
plt.tight_layout()
plt.show()

# %%
# Взаимодействие между возрастом и функцией щитовидной железы
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Thyroid Function', hue='Recurred', data=df)
plt.title('Взаимодействие между возрастом и функцией щитовидной железы')
plt.xlabel('Возраст')
plt.ylabel('Функция щитовидной железы')
plt.show()

# %%
# Кросс-табуляция между полом и рецидивом
cross_tab = pd.crosstab(df['Gender'], df['Recurred'])
cross_tab.plot(kind='bar', stacked=True, figsize=(8, 5))
plt.title('Кросс-табуляция: Пол и Рецидив')
plt.xlabel('Пол')
plt.ylabel('Количество')
plt.legend(title='Рецидив')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')


categorical_columns = df.select_dtypes(include=['object']).columns

# Круговые диаграммы для категориальных переменных
plt.figure(figsize=(15, 10))
for i, column in enumerate(categorical_columns):
    plt.subplot(4, 4, i + 1)
    df[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, fontsize=10)
    plt.title(column)
    plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/differentiated-thyroid-cancer-recurrence/Thyroid_Diff.csv')

# Список категориальных классов
categorical_columns = [ 'Gender', 'Smoking', 'Hx Smoking',
                   'Thyroid Function', 'Physical Examination', 'Adenopathy',
                   'Pathology', 'Focality', 'Risk', 'T', 'N', 'M', 'Stage',
                   'Response', 'Recurred']

# Создание диаграмм счетчиков
plt.figure(figsize=(15, 20))
for i, column in enumerate(categorical_columns):
    plt.subplot(4, 3, i + 1)
    sns.countplot(x=column, data=df)
    plt.title(column)
    plt.xticks(rotation=45)
    plt.xlabel(column)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-7f224444a02c> in <cell line: 0>()
#      14 plt.figure(figsize=(15, 20))
#      15 for i, column in enumerate(categorical_columns):
# ---> 16     plt.subplot(4, 3, i + 1)
#      17     sns.countplot(x=column, data=df)
#      18     plt.title(column)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     587         else:
#     588             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589                 raise ValueError(
# ...

# %%
# создает список ,который содержит названия всех категориальных столбцов в DataFrame
cat_cols=list(df.select_dtypes(include=object).iloc[:,:-1].columns)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


plt.figure(figsize=(16, len(cat_cols) * 2))

# Создание цветовой карты
cmap = sns.diverging_palette(90, 7, s=75, l=40, n=7, center='light', as_cmap=True)

# Цикл по категориальным столбцам
for i, col in enumerate(cat_cols):
    plt.subplot(len(cat_cols) // 2 + len(cat_cols) % 2, 2, i + 1)
    crosstab_data = pd.crosstab(df[col], df['Recurred'], normalize='index')
    sns.heatmap(data=crosstab_data, annot=True, cmap=cmap, fmt='.2f')
    plt.title(f"{col} recurred")

plt.tight_layout()
plt.show()

# %%
#преобразование категориальных переменных в числовые
for col in cat_cols:
    df[col]=df[col].astype('category').cat.codes


df['Recurred']=df['Recurred'].astype('category').cat.codes
df
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 2
# 1     34       0        0           1                0                 2
# 2     30       0        0           0                0                 2
# 3     62       0        0           0                0                 2
# 4     62       0        0           0                0                 2
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 2
# 379   81       1        1           0                1                 2
# 380   72       1        1           1                0                 2
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 2
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T  N  M  \
# ...

# %%
#анализ корреляции между числовыми переменными в DataFrame
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df['Recurred'] = df['Recurred'].map({'No': 0, 'Yes': 1})

corr_mat = df.iloc[:, 0:-1].astype(int).corr()

corr_mask = np.triu(np.ones_like(corr_mat, dtype=bool))

cmap = sns.color_palette("viridis", as_cmap=True)

plt.figure(figsize=(16, 12))
sns.heatmap(corr_mat, annot=True, cmap=cmap, fmt='.2f', center=0,
            annot_kws={'size': 10, 'weight': 'bold', 'color': 'black'},
            mask=corr_mask, linewidths=0.5, linecolor='gray')
plt.title('Корреляции между входными признаками', fontsize=20, weight='bold')
plt.show()

# %%
# подготовка датасета

# Разделение данных для обучения и тестирования
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(df.iloc[:,0:-1], df.iloc[:,-1], test_size= 0.25, random_state=10)
print('X_train shape:',X_train.shape)
print('X_test shape:',X_test.shape)
print('y_train shape:',y_train.shape)
print('y_test shape:',y_test.shape)
# Out:
# X_train shape: (287, 16)
# X_test shape: (96, 16)
# y_train shape: (287,)
# y_test shape: (96,)

# %%
# стандартизирование обучающей и тестовой выборки
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train= scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
# импорт бибилиотек
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# создание экземпляров алгоритмов
sm = SMOTE(sampling_strategy='auto', random_state = 1, k_neighbors=5)
tk = TomekLinks(sampling_strategy='auto')

# создание экземпляра SMOTETomek
# он сначала применяет SMOTE для увеличения меньшинства, а затем применяет Tomek Links для удаления образцов, которые могут быть шумом или находиться на границе между классами
smtk = SMOTETomek(sampling_strategy='auto', smote=sm, tomek=tk, random_state = 1)

# обучающим данным X_train и y_train, чтобы сбалансировать классы
X_over_under, y_over_under = smtk.fit_resample(X_train, y_train)
X_train=X_over_under
y_train=y_over_under

# %%
# Логистическая регрессия
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
predictions1 = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

print("Confusion Matrix: \n", confusion_matrix(y_test, predictions1))
print('\n')
print(classification_report(y_test, predictions1))
logreg_acc = accuracy_score(y_test, predictions1)
print("Accuracy of the Logistic Regression Model is: ", logreg_acc)
# Out:
# Confusion Matrix:
#  [[70  4]
#  [ 4 18]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        74
#            1       0.82      0.82      0.82        22
#
#     accuracy                           0.92        96
#    macro avg       0.88      0.88      0.88        96
# weighted avg       0.92      0.92      0.92        96
#
# Accuracy of the Logistic Regression Model is:  0.9166666666666666

# %% [markdown]
# Точность 0.92

# %%
# метод опорных векторов
from sklearn.svm import SVC

svc_model = SVC(kernel="rbf")
svc_model.fit(X_train, y_train)
predictions3 = svc_model.predict(X_test)

# %%
print("Confusion Matrix: \n", confusion_matrix(y_test, predictions3))
print("\n")
print(classification_report(y_test, predictions3))
svm_acc = accuracy_score(y_test, predictions3)
print("Accuracy of SVM model is: ", svm_acc)
# Out:
# Confusion Matrix:
#  [[72  2]
#  [ 4 18]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        74
#            1       0.90      0.82      0.86        22
#
#     accuracy                           0.94        96
#    macro avg       0.92      0.90      0.91        96
# weighted avg       0.94      0.94      0.94        96
#
# Accuracy of SVM model is:  0.9375

# %% [markdown]
# Точность 0.94

# %%
# градиентный бустинг
# создание и обучение модели на тренировочных данных
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier()
gb_model.fit(X_train, y_train)
predictions5= gb_model.predict(X_test)

# %%
# получение отчета о классификации
# вывод общей точности
print("Confusion Matrix: \n", confusion_matrix(y_test, predictions5))
print("\n")
print(classification_report(y_test, predictions5))
gboost_acc= accuracy_score(y_test, predictions5)
print("Accuracy of XGBOOST model is: ", gboost_acc)
# Out:
# Confusion Matrix:
#  [[73  1]
#  [ 2 20]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        74
#            1       0.95      0.91      0.93        22
#
#     accuracy                           0.97        96
#    macro avg       0.96      0.95      0.96        96
# weighted avg       0.97      0.97      0.97        96
#
# Accuracy of XGBOOST model is:  0.96875

# %% [markdown]
# Точность 0.97

# %% [markdown]
# **Вывод:** таким образом, лучшего всего себя показал градиентный бустинг с точностью 0.97 и f1 score 0.94, а хуже всего логистическая регрессия с точностью 0.92 и f1 score 0.82.
